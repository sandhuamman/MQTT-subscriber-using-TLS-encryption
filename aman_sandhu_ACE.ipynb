# %%
pip install paho-mqtt
# Out:
# Requirement already satisfied: paho-mqtt in /usr/local/lib/python3.10/dist-packages (2.1.0)

# %%
import paho.mqtt.client as mqtt
import time
import random
import ssl

# %%
BROKER = "test.mosquitto.org"
PORT = 8883
TOPIC = "telemeter/sensors/temperature"
CLIENT_ID = "SensorPublisher"
USERNAME = "your_username"
PASSWORD = "your_password"

# %%
client = mqtt.Client(client_id=CLIENT_ID)
client.tls_set(cert_reqs=ssl.CERT_NONE)
client.tls_insecure_set(True)
client.username_pw_set(USERNAME, PASSWORD)
# Out:
# <ipython-input-19-f1e32618bd60>:1: DeprecationWarning: Callback API version 1 is deprecated, update to latest version
#   client = mqtt.Client(client_id=CLIENT_ID)

# %%
client.connect(BROKER, PORT, 60)
# Out:
# <MQTTErrorCode.MQTT_ERR_SUCCESS: 0>

# %%
def publish_sensor_data():
    """Simulate and publish sensor data."""
    try:
        while True:
            temperature = round(random.uniform(20.0, 30.0), 2)  # Simulated temperature
            message = {"sensor_id": CLIENT_ID, "temperature": temperature, "unit": "C"}
            client.publish(TOPIC, str(message))
            print(f"Published: {message}")
            time.sleep(5)  # Publish every 5 seconds
    except KeyboardInterrupt:
        print("Stopping publisher...")
        client.disconnect()

# %%
publish_sensor_data()
# Out:
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 24.02, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 22.21, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 28.51, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 21.62, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 29.17, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 29.84, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 29.81, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 24.14, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 24.08, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 29.45, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 25.74, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 26.89, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 28.85, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 22.78, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 25.57, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 21.03, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 27.41, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 23.1, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 26.66, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 24.15, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 27.33, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 21.92, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 25.66, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 23.06, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 27.22, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 28.2, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 25.16, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 23.08, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 27.76, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 27.46, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 24.68, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 22.06, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 23.58, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 29.53, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 21.63, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 28.98, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 29.38, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 28.9, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 26.05, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 26.2, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 29.31, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 22.66, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 27.45, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 28.05, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 23.31, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 21.97, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 20.7, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 28.25, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 25.08, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 27.13, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 28.71, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 21.35, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 29.64, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 28.29, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 21.22, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 23.68, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 25.74, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 23.19, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 23.75, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 20.33, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 22.6, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 20.18, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 21.87, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 26.15, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 27.7, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 23.45, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 26.57, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 26.19, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 21.27, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 20.51, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 20.63, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 27.83, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 25.75, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 26.56, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 20.01, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 29.12, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 20.86, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 28.49, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 21.68, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 24.29, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 29.61, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 27.03, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 27.41, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 28.42, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 21.48, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 28.85, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 26.73, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 24.78, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 27.95, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 25.3, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 27.86, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 23.96, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 26.53, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 27.77, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 22.62, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 21.82, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 23.12, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 27.45, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 28.33, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 25.57, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 22.48, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 28.26, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 20.19, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 29.85, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 27.16, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 24.88, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 28.71, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 28.21, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 20.17, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 22.0, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 20.12, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 23.35, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 27.34, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 21.61, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 21.46, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 25.49, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 20.69, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 23.47, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 20.01, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 26.43, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 29.04, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 28.36, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 24.0, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 24.23, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 22.84, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 22.77, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 23.63, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 22.34, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 20.93, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 21.5, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 20.37, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 20.45, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 22.11, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 28.6, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 24.94, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 20.8, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 23.18, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 20.31, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 22.77, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 22.93, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 23.27, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 21.3, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 22.32, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 25.41, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 27.62, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 20.89, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 25.8, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 21.81, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 27.46, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 23.87, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 20.04, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 27.81, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 29.74, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 21.59, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 22.52, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 23.69, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 25.17, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 26.44, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 26.8, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 20.48, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 24.97, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 26.11, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 25.31, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 20.07, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 20.23, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 22.0, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 29.59, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 25.96, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 26.97, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 28.85, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 21.87, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 28.7, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 20.95, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 24.19, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 23.07, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 25.76, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 28.1, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 29.0, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 28.68, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 20.5, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 21.62, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 20.4, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 22.81, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 24.96, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 24.76, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 28.58, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 23.78, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 28.74, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 28.6, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 25.66, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 27.07, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 23.2, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 23.91, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 27.75, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 20.33, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 23.26, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 22.45, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 21.48, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 26.95, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 24.49, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 24.66, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 25.44, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 23.45, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 27.52, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 28.17, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 25.56, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 24.14, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 21.01, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 26.48, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 29.36, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 26.21, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 21.13, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 29.05, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 29.35, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 20.42, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 20.8, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 26.23, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 28.5, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 24.94, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 22.12, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 24.98, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 26.3, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 27.35, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 22.49, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 29.62, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 23.37, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 28.48, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 29.27, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 29.17, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 20.15, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 22.48, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 26.16, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 24.99, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 25.72, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 26.91, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 28.94, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 21.93, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 26.72, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 25.2, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 28.14, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 27.28, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 27.79, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 24.91, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 27
 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 26.3, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 25.17, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 22.59, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 28.82, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 20.56, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 21.33, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 21.83, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 28.5, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 28.5, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 24.67, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 22.86, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 25.94, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 21.06, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 23.77, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 20.94, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 26.47, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 21.03, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 22.73, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 22.05, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 21.74, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 25.91, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 27.25, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 24.52, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 27.39, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 22.43, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 28.51, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 23.99, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 29.77, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 25.6, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 21.41, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 29.23, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 28.98, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 27.05, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 22.66, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 24.66, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 26.55, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 25.85, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 26.81, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 22.41, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 27.91, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 23.13, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 23.61, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 21.02, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 25.32, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 29.95, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 25.75, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 29.84, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 25.92, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 29.14, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 22.0, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 24.73, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 25.34, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 22.75, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 22.64, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 25.23, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 21.82, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 20.1, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 24.67, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 27.35, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 27.42, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 28.18, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 21.63, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 29.66, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 21.01, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 20.63, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 24.47, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 23.56, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 20.57, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 25.71, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 24.39, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 26.02, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 29.54, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 20.78, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 28.15, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 28.94, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 20.41, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 27.4, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 24.27, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 27.28, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 28.49, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 23.33, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 29.53, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 29.03, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 27.76, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 26.96, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 27.71, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 29.36, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 27.97, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 29.98, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 20.21, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 21.5, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 23.19, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 23.28, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 22.15, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 28.49, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 20.9, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 28.66, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 27.93, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 20.81, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 25.45, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 23.7, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 27.96, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 28.0, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 26.34, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 22.51, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 26.25, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 26.91, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 23.11, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 26.26, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 24.7, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 27.25, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 24.83, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 29.04, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 28.06, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 25.64, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 22.71, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 28.1, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 27.37, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 26.83, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 27.88, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 26.58, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 21.32, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 20.79, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 28.11, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 24.38, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 28.22, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 24.95, 'unit': 'C'}
# Published: {'sensor_id': 'DashboardSubscriber', 'temperature': 25.44, 'unit': 'C'}

# %%
import paho.mqtt.client as mqtt
import ssl

# %%
BROKER = "test.mosquitto.org"
PORT = 8883
TOPIC = "telemeter/sensors/temperature"
CLIENT_ID = "DashboardSubscriber"

# %%
client = mqtt.Client(client_id=CLIENT_ID)
client.tls_set(cert_reqs=ssl.CERT_NONE)  # Disable certificate verification
client.tls_insecure_set(True)  # Allow insecure connection
# Out:
# <ipython-input-24-d359b7cbccae>:1: DeprecationWarning: Callback API version 1 is deprecated, update to latest version
#   client = mqtt.Client(client_id=CLIENT_ID)

# %%
def on_connect(client, userdata, flags, rc):
    """Callback when connected to the broker."""
    print(f"Connected to broker with result code {rc}")
    client.subscribe(TOPIC)

# %%
def on_message(client, userdata, msg):
    """Callback when a message is received."""
    print(f"Received message: {msg.payload.decode()}")

# %%
client.on_connect = on_connect
client.on_message = on_message

# %%
client.connect(BROKER, PORT, 60)
# Out:
# <MQTTErrorCode.MQTT_ERR_SUCCESS: 0>

# %%
client.loop_forever()
# Out:
# Connected to broker with result code 0
# Connected to broker with result code 0
# Connected to broker with result code 0
# Connected to broker with result code 0
# Connected to broker with result code 0
# Connected to broker with result code 0
# Connected to broker with result code 0
# Connected to broker with result code 0
# Connected to broker with result code 0
# Connected to broker with result code 0
# Connected to broker with result code 0
# Connected to broker with result code 0
# Connected to broker with result code 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-331526b62073> in <cell line: 1>()
# ----> 1 client.loop_forever()
#
# /usr/local/lib/python3.10/dist-packages/paho/mqtt/client.py in loop_forever(self, timeout, retry_first_connection)
#    2295             rc = MQTTErrorCode.MQTT_ERR_SUCCESS
#    2296             while rc == MQTTErrorCode.MQTT_ERR_SUCCESS:
# -> 2297                 rc = self._loop(timeout)
#    2298                 # We don't need to worry about locking here, because we've
#    2299                 # either called loop_forever() when in single threaded mode, or
#
# /usr/local/lib/python3.10/dist-packages/paho/mqtt/client.py in _loop(self, timeout)
#    1661
#    1662         try:
# -> 1663             socklist = select.select(rlist, wlist, [], timeout)
#    1664         except TypeError:
#    1665             # Socket isn't correct type, in likelihood connection is lost
#
# KeyboardInterrupt:
